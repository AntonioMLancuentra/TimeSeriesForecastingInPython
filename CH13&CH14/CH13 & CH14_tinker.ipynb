# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.20.0

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/train.csv', index_col=0)
val_df = pd.read_csv('../data/val.csv', index_col=0)
test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %% [markdown]
# # Chapter 13

# %% [markdown]
# ## 13.1 Creating windows of data
# ### 13.1.1 Exploring how deep learning models are trained for time series forecasting

# %%
fig, ax = plt.subplots()

for n in range(0,17,2):
    start = 24*n
    stop = 24*(n+1)
    ax.plot(train_df.traffic_volume[start:stop], marker='s', color='blue', label='input')
    ax.plot(train_df.traffic_volume[stop:2*stop], marker='x', color='red', label='label')
ax.set_xlabel('Time')
ax.set_ylabel('Traffic volume')

plt.xticks(np.arange(7, 400, 24), ['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.xlim(0, 400)

fig.autofmt_xdate()
plt.tight_layout()

# plt.savefig('figures/CH13_F01_peixeiro.png', dpi=300)

# %% [markdown]
# ### 13.1.2 Implementing the `DataWindow` class

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %% [markdown]
# ## 13.2 Applying baseline models
# ### 13.2.1 Single-step baseline model

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['traffic_volume']) 
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['traffic_volume'])

# %%
class Baseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return inputs
        
        elif isinstance(self.label_index, list):
            tensors = []
            for index in self.label_index:
                result = inputs[:, :, index]
                result = result[:, :, tf.newaxis]
                tensors.append(result)
            return tf.concat(tensors, axis=-1)
        
        result = inputs[:, :, self.label_index]
        return result[:,:,tf.newaxis]

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

baseline_last = Baseline(label_index=column_indices['traffic_volume'])

baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771473343.211637   14706 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9608 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1

# %%
val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.test, verbose=0)
# Out:
#  27/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0127 - mean_absolute_error: 0.0808
# 2026-02-18 22:55:50.984055: I external/local_xla/xla/service/service.cc:163] XLA service 0x7895e40037d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-18 22:55:50.984071: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2026-02-18 22:55:50.997796: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-18 22:55:51.008115: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91900
# I0000 00:00:1771473351.084868   19438 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0831

# %%
wide_window.plot(baseline_last)

plt.savefig('figures/CH13_F09_peixeiro.png', dpi=300)

# %%
print(performance['Baseline - Last'][1])
# Out:
# 0.08128398656845093

# %% [markdown]
# ### 13.2.2 Multi-step baseline models

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# %% [markdown]
# #### Predicting the last known value

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 24, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 24, 1])

# %%
ms_baseline_last = MultiStepLastBaseline(label_index=column_indices['traffic_volume'])

ms_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance = {}
ms_performance = {}

ms_val_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.val)
ms_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.test, verbose=0)
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1875 - mean_absolute_error: 0.3522

# %%
multi_window.plot(ms_baseline_last)

plt.savefig('figures/CH13_F10_peixeiro.png', dpi=300)

# %%
print(ms_performance['Baseline - Last'][1])
# Out:
# 0.34726080298423767

# %% [markdown]
# #### Repeating the input sequence

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
ms_baseline_repeat = RepeatBaseline(label_index=column_indices['traffic_volume'])

ms_baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.val)
ms_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2065 - mean_absolute_error: 0.3473

# %%
multi_window.plot(ms_baseline_repeat)

plt.savefig('figures/CH13_F11_peixeiro.png', dpi=300)

# %%
print(ms_performance['Baseline - Repeat'][1])
# Out:
# 0.34127721190452576

# %% [markdown]
# ### 13.2.3 Multi-output baseline model

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['temp','traffic_volume']) 
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['temp','traffic_volume'])

# %%
print(column_indices['traffic_volume'])
print(column_indices['temp'])
# Out:
# 2
# 0

# %%
mo_baseline_last = Baseline(label_index=[0, 2])

mo_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

mo_val_performance = {}
mo_performance = {}

mo_val_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.val)
mo_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.test, verbose=0)
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0482

# %%
mo_wide_window.plot(mo_baseline_last)

plt.savefig('figures/CH13_F12_peixeiro.png', dpi=300)

# %%
mo_wide_window.plot(model=mo_baseline_last, plot_col='temp')

plt.savefig('figures/CH13_F13_peixeiro.png', dpi=300)

# %%
print(mo_performance['Baseline - Last'][1])
# Out:
# 0.047106657177209854

# %% [markdown]
# # Chapter 14

# %% [markdown]
# ## 14.1 Implementing a linear model
# ### 14.1.1 Building a single-step linear model

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
linear = Sequential([
    Dense(units=1)
])

history = compile_and_fit(linear, single_step_window)

val_performance['Linear'] = linear.evaluate(single_step_window.val)
performance['Linear'] = linear.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4981 - mean_absolute_error: 0.5960 - val_loss: 0.3161 - val_mean_absolute_error: 0.4899
# Epoch 2/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2038 - mean_absolute_error: 0.3875 - val_loss: 0.1301 - val_mean_absolute_error: 0.3127
# Epoch 3/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0810 - mean_absolute_error: 0.2404 - val_loss: 0.0491 - val_mean_absolute_error: 0.1877
# Epoch 4/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0316 - mean_absolute_error: 0.1440 - val_loss: 0.0206 - val_mean_absolute_error: 0.1122
# Epoch 5/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0156 - mean_absolute_error: 0.0935 - val_loss: 0.0125 - val_mean_absolute_error: 0.0780
# Epoch 6/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0114 - mean_absolute_error: 0.0765 - val_loss: 0.0106 - val_mean_absolute_error: 0.0692
# Epoch 7/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - mean_absolute_error: 0.0733 - val_loss: 0.0101 - val_mean_absolute_error: 0.0678
# Epoch 8/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0102 - mean_absolute_error: 0.0725 - val_loss: 0.0099 - val_mean_absolute_error: 0.0676
# Epoch 9/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0720 - val_loss: 0.0098 - val_mean_absolute_error: 0.0664
# Epoch 10/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0712 - val_loss: 0.0096 - val_mean_absolute_error: 0.0667
# Epoch 11/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0706 - val_loss: 0.0095 - val_mean_absolute_error: 0.0658
# Epoch 12/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0699 - val_loss: 0.0094 - val_mean_absolute_error: 0.0662
# Epoch 13/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0693 - val_loss: 0.0093 - val_mean_absolute_error: 0.0656
# Epoch 14/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.0690 - val_loss: 0.0092 - val_mean_absolute_error: 0.0657
# Epoch 15/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.0686 - val_loss: 0.0092 - val_mean_absolute_error: 0.0646
# Epoch 16/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0683 - val_loss: 0.0091 - val_mean_absolute_error: 0.0649
# Epoch 17/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0681 - val_loss: 0.0092 - val_mean_absolute_error: 0.0641
# Epoch 18/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0679 - val_loss: 0.0091 - val_mean_absolute_error: 0.0649
# Epoch 19/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.0679 - val_loss: 0.0091 - val_mean_absolute_error: 0.0646
# Epoch 20/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0641
# Epoch 21/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0677 - val_loss: 0.0091 - val_mean_absolute_error: 0.0643
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0091 - mean_absolute_error: 0.0643

# %%
wide_window.plot(linear)

plt.savefig('figures/CH14_F02_peixeiro.png', dpi=300)

# %% [markdown]
# ### 14.1.2 Building a mutli-step linear model

# %%
ms_linear = Sequential([
    Dense(1, kernel_initializer=tf.initializers.zeros)
])

history = compile_and_fit(ms_linear, multi_window)

ms_val_performance['Linear'] = ms_linear.evaluate(multi_window.val)
ms_performance['Linear'] = ms_linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0898 - mean_absolute_error: 0.2465 - val_loss: 0.0457 - val_mean_absolute_error: 0.1821
# Epoch 2/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0298 - mean_absolute_error: 0.1368 - val_loss: 0.0261 - val_mean_absolute_error: 0.1252
# Epoch 3/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0200 - mean_absolute_error: 0.1044 - val_loss: 0.0212 - val_mean_absolute_error: 0.1074
# Epoch 4/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0177 - mean_absolute_error: 0.0955 - val_loss: 0.0196 - val_mean_absolute_error: 0.1000
# Epoch 5/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0168 - mean_absolute_error: 0.0914 - val_loss: 0.0188 - val_mean_absolute_error: 0.0952
# Epoch 6/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0887 - val_loss: 0.0184 - val_mean_absolute_error: 0.0924
# Epoch 7/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0162 - mean_absolute_error: 0.0869 - val_loss: 0.0183 - val_mean_absolute_error: 0.0903
# Epoch 8/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0162 - mean_absolute_error: 0.0857 - val_loss: 0.0182 - val_mean_absolute_error: 0.0894
# Epoch 9/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0161 - mean_absolute_error: 0.0850 - val_loss: 0.0182 - val_mean_absolute_error: 0.0887
# Epoch 10/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0161 - mean_absolute_error: 0.0846 - val_loss: 0.0181 - val_mean_absolute_error: 0.0885
# Epoch 11/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0161 - mean_absolute_error: 0.0843 - val_loss: 0.0181 - val_mean_absolute_error: 0.0884
# Epoch 12/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.0841 - val_loss: 0.0182 - val_mean_absolute_error: 0.0880
# Epoch 13/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.0840 - val_loss: 0.0182 - val_mean_absolute_error: 0.0881
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - mean_absolute_error: 0.0881

# %% [markdown]
# ### 14.1.3 Implementing a multi-output linear model

# %%
mo_linear = Sequential([
    Dense(units=2)
])

history = compile_and_fit(mo_linear, mo_single_step_window)

mo_val_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.val)
mo_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1791 - mean_absolute_error: 0.3362 - val_loss: 0.1039 - val_mean_absolute_error: 0.2607
# Epoch 2/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0636 - mean_absolute_error: 0.2051 - val_loss: 0.0426 - val_mean_absolute_error: 0.1695
# Epoch 3/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0280 - mean_absolute_error: 0.1386 - val_loss: 0.0212 - val_mean_absolute_error: 0.1206
# Epoch 4/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0163 - mean_absolute_error: 0.1042 - val_loss: 0.0138 - val_mean_absolute_error: 0.0963
# Epoch 5/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.0860 - val_loss: 0.0102 - val_mean_absolute_error: 0.0809
# Epoch 6/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.0738 - val_loss: 0.0081 - val_mean_absolute_error: 0.0693
# Epoch 7/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0640 - val_loss: 0.0067 - val_mean_absolute_error: 0.0595
# Epoch 8/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0560 - val_loss: 0.0059 - val_mean_absolute_error: 0.0521
# Epoch 9/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0060 - mean_absolute_error: 0.0497 - val_loss: 0.0053 - val_mean_absolute_error: 0.0460
# Epoch 10/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0453 - val_loss: 0.0050 - val_mean_absolute_error: 0.0421
# Epoch 11/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0053 - mean_absolute_error: 0.0426 - val_loss: 0.0049 - val_mean_absolute_error: 0.0402
# Epoch 12/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0410 - val_loss: 0.0048 - val_mean_absolute_error: 0.0387
# Epoch 13/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0401 - val_loss: 0.0047 - val_mean_absolute_error: 0.0382
# Epoch 14/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0396 - val_loss: 0.0047 - val_mean_absolute_error: 0.0378
# Epoch 15/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0381
# Epoch 16/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0394 - val_loss: 0.0047 - val_mean_absolute_error: 0.0380
# Epoch 17/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0047 - val_mean_absolute_error: 0.0377
# Epoch 18/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0047 - val_mean_absolute_error: 0.0376
# Epoch 19/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0376
# Epoch 20/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0047 - val_mean_absolute_error: 0.0375
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0375

# %% [markdown]
# ## 14.2 Implementing a deep neural network
# ### 14.2.1 Implementing a deep neural network as a single-step model

# %%
dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=1)
])

history = compile_and_fit(dense, single_step_window)

val_performance['Dense'] = dense.evaluate(single_step_window.val)
performance['Dense'] = dense.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0142 - mean_absolute_error: 0.0747 - val_loss: 0.0051 - val_mean_absolute_error: 0.0549
# Epoch 2/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0489 - val_loss: 0.0034 - val_mean_absolute_error: 0.0442
# Epoch 3/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0441 - val_loss: 0.0040 - val_mean_absolute_error: 0.0483
# Epoch 4/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0426 - val_loss: 0.0030 - val_mean_absolute_error: 0.0423
# Epoch 5/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0032 - mean_absolute_error: 0.0407 - val_loss: 0.0033 - val_mean_absolute_error: 0.0451
# Epoch 6/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0400 - val_loss: 0.0028 - val_mean_absolute_error: 0.0393
# Epoch 7/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0030 - mean_absolute_error: 0.0390 - val_loss: 0.0028 - val_mean_absolute_error: 0.0407
# Epoch 8/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0029 - mean_absolute_error: 0.0384 - val_loss: 0.0032 - val_mean_absolute_error: 0.0430
# Epoch 9/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0028 - mean_absolute_error: 0.0378 - val_loss: 0.0034 - val_mean_absolute_error: 0.0461
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0461

# %%
wide_window.plot(dense)

plt.savefig('figures/CH14_F06_peixeiro.png', dpi=300)

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH14_F07_peixeiro.png', dpi=300)

# %% [markdown]
# ### 14.2.2 Implementing a deep neural network as a multi-step model

# %%
ms_dense = Sequential([
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_dense, multi_window)

ms_val_performance['Dense'] = ms_dense.evaluate(multi_window.val)
ms_performance['Dense'] = ms_dense.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0292 - mean_absolute_error: 0.1097 - val_loss: 0.0164 - val_mean_absolute_error: 0.0824
# Epoch 2/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0137 - mean_absolute_error: 0.0779 - val_loss: 0.0161 - val_mean_absolute_error: 0.0811
# Epoch 3/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0133 - mean_absolute_error: 0.0771 - val_loss: 0.0152 - val_mean_absolute_error: 0.0841
# Epoch 4/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0764 - val_loss: 0.0150 - val_mean_absolute_error: 0.0779
# Epoch 5/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0760 - val_loss: 0.0147 - val_mean_absolute_error: 0.0801
# Epoch 6/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0755 - val_loss: 0.0147 - val_mean_absolute_error: 0.0783
# Epoch 7/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0758 - val_loss: 0.0151 - val_mean_absolute_error: 0.0819
# Epoch 8/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0754 - val_loss: 0.0150 - val_mean_absolute_error: 0.0793
# Epoch 9/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0756 - val_loss: 0.0150 - val_mean_absolute_error: 0.0769
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0150 - mean_absolute_error: 0.0769

# %%
ms_mae_val = [v[1] for v in ms_val_performance.values()]
ms_mae_test = [v[1] for v in ms_performance.values()]

x = np.arange(len(ms_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=ms_performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH14_F08_peixeiro.png', dpi=300)

# %% [markdown]
# ### 14.2.3 Implementing a deep neural network as a multi-output model

# %%
mo_dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=2)
])

history = compile_and_fit(mo_dense, mo_single_step_window)

mo_val_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.val)
mo_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0166 - mean_absolute_error: 0.0704 - val_loss: 0.0030 - val_mean_absolute_error: 0.0345
# Epoch 2/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0337 - val_loss: 0.0022 - val_mean_absolute_error: 0.0300
# Epoch 3/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0024 - mean_absolute_error: 0.0313 - val_loss: 0.0018 - val_mean_absolute_error: 0.0277
# Epoch 4/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0287 - val_loss: 0.0016 - val_mean_absolute_error: 0.0260
# Epoch 5/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0275 - val_loss: 0.0016 - val_mean_absolute_error: 0.0254
# Epoch 6/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0271 - val_loss: 0.0015 - val_mean_absolute_error: 0.0252
# Epoch 7/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0260 - val_loss: 0.0015 - val_mean_absolute_error: 0.0255
# Epoch 8/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0258 - val_loss: 0.0014 - val_mean_absolute_error: 0.0252
# Epoch 9/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0016 - val_mean_absolute_error: 0.0261
# Epoch 10/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0013 - val_mean_absolute_error: 0.0224
# Epoch 11/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0013 - val_mean_absolute_error: 0.0228
# Epoch 12/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0012 - val_mean_absolute_error: 0.0216
# Epoch 13/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0245 - val_loss: 0.0012 - val_mean_absolute_error: 0.0228
# Epoch 14/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.0012 - val_mean_absolute_error: 0.0218
# Epoch 15/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 0.0012 - val_mean_absolute_error: 0.0237
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0237

# %%
mo_mae_val = [v[1] for v in mo_val_performance.values()]
mo_mae_test = [v[1] for v in mo_performance.values()]

x = np.arange(len(mo_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=mo_performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH14_F09_peixeiro.png', dpi=300)
