# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

# GPU running out of memory, testing enabling memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)
# GPU running out of memory, testing enabling memory growth

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/ex_train.csv')
val_df = pd.read_csv('../data/ex_val.csv')
test_df = pd.read_csv('../data/ex_test.csv')

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (13239, 12) (3783, 12) (1892, 12)

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='NO2', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# # Chapter 13

# %% [markdown]
# ## Single-step
# ### Baseline

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['NO2']) 
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['NO2'])

# %%
class Baseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return inputs
        
        elif isinstance(self.label_index, list):
            tensors = []
            for index in self.label_index:
                result = inputs[:, :, index]
                result = result[:, :, tf.newaxis]
                tensors.append(result)
            return tf.concat(tensors, axis=-1)
        
        result = inputs[:, :, self.label_index]
        return result[:,:,tf.newaxis]

# %%
baseline_last = Baseline(label_index=column_indices['NO2'])

baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771475686.338522   30364 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9702 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1

# %%
val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.test, verbose=0)
# Out:
#  35/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0268
# 2026-02-18 23:34:47.727279: I external/local_xla/xla/service/service.cc:163] XLA service 0x7ea7540158f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-18 23:34:47.727296: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2026-02-18 23:34:47.738292: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-18 23:34:47.750502: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91900
# I0000 00:00:1771475687.837295   30400 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0287

# %%
wide_window.plot(baseline_last)

# %% [markdown]
# ## Multi-step
# ### Baseline

# %% [markdown]
# #### Repeast last value

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['NO2'])

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 24, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 24, 1])

# %%
ms_baseline_last = MultiStepLastBaseline(label_index=column_indices['NO2'])

ms_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance = {}
ms_performance = {}

ms_val_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.val)
ms_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.test, verbose=0)
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1443 - mean_absolute_error: 0.2821

# %%
multi_window.plot(ms_baseline_last)

# %% [markdown]
# #### Repeat last season

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
ms_baseline_repeat = RepeatBaseline(label_index=column_indices['NO2'])

ms_baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.val)
ms_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1426 - mean_absolute_error: 0.2818

# %%
multi_window.plot(ms_baseline_repeat)

# %% [markdown]
# ## Multi-output
# ### Baseline

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['NO2','TEMP']) 
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['NO2','TEMP'])

# %%
print(column_indices['NO2'])
print(column_indices['TEMP'])
# Out:
# 3
# 6

# %%
mo_baseline_last = Baseline(label_index=[3, 6])

mo_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

mo_val_performance = {}
mo_performance = {}

mo_val_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.val)
mo_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.test, verbose=0)
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0215

# %%
mo_wide_window.plot(mo_baseline_last)

# %% [markdown]
# # Chapter 14

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
# def compile_and_fit(model, window, batch_size=32, patience=3, max_epochs=50):
#     early_stopping = EarlyStopping(monitor='val_loss',
#                                    patience=patience,
#                                    mode='min')
    
#     model.compile(loss=MeanSquaredError(),
#                   optimizer=Adam(),
#                   metrics=[MeanAbsoluteError()])
    
#     history = model.fit(window.train.unbatch().batch(batch_size),
#                        epochs=max_epochs,
#                        validation_data=window.val.unbatch().batch(batch_size),
#                        callbacks=[early_stopping])
    
#     return history

# %% [markdown]
# ## Single-step

# %% [markdown]
# ### Linear model

# %%
linear = Sequential([
    Dense(units=1)
])

history = compile_and_fit(linear, single_step_window)

val_performance['Linear'] = linear.evaluate(single_step_window.val)
performance['Linear'] = linear.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0289 - mean_absolute_error: 0.1374 - val_loss: 0.0158 - val_mean_absolute_error: 0.1007
# Epoch 2/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0090 - mean_absolute_error: 0.0741 - val_loss: 0.0075 - val_mean_absolute_error: 0.0707
# Epoch 3/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0532 - val_loss: 0.0045 - val_mean_absolute_error: 0.0537
# Epoch 4/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0427 - val_loss: 0.0029 - val_mean_absolute_error: 0.0409
# Epoch 5/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0368 - val_loss: 0.0025 - val_mean_absolute_error: 0.0365
# Epoch 6/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0330 - val_loss: 0.0023 - val_mean_absolute_error: 0.0339
# Epoch 7/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0305 - val_loss: 0.0021 - val_mean_absolute_error: 0.0305
# Epoch 8/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0289 - val_loss: 0.0020 - val_mean_absolute_error: 0.0284
# Epoch 9/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0278 - val_loss: 0.0020 - val_mean_absolute_error: 0.0282
# Epoch 10/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0272 - val_loss: 0.0020 - val_mean_absolute_error: 0.0282
# Epoch 11/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0269 - val_loss: 0.0020 - val_mean_absolute_error: 0.0283
# Epoch 12/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0267 - val_loss: 0.0020 - val_mean_absolute_error: 0.0275
# Epoch 13/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0265 - val_loss: 0.0020 - val_mean_absolute_error: 0.0278
# Epoch 14/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0265 - val_loss: 0.0020 - val_mean_absolute_error: 0.0274
# Epoch 15/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0265 - val_loss: 0.0019 - val_mean_absolute_error: 0.0274
# Epoch 16/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0265 - val_loss: 0.0020 - val_mean_absolute_error: 0.0279
# Epoch 17/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0264 - val_loss: 0.0019 - val_mean_absolute_error: 0.0274
# Epoch 18/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0264 - val_loss: 0.0020 - val_mean_absolute_error: 0.0278
# Epoch 19/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0265 - val_loss: 0.0020 - val_mean_absolute_error: 0.0284
# Epoch 20/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0265 - val_loss: 0.0019 - val_mean_absolute_error: 0.0274
# Epoch 21/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0264 - val_loss: 0.0019 - val_mean_absolute_error: 0.0275
# Epoch 22/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0263 - val_loss: 0.0019 - val_mean_absolute_error: 0.0274
# Epoch 23/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0264 - val_loss: 0.0019 - val_mean_absolute_error: 0.0274
# Epoch 24/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0264 - val_loss: 0.0019 - val_mean_absolute_error: 0.0274
# Epoch 25/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0264 - val_loss: 0.0020 - val_mean_absolute_error: 0.0280
# Epoch 26/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0264 - val_loss: 0.0019 - val_mean_absolute_error: 0.0274
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0274

# %%
wide_window.plot(linear)

# %% [markdown]
# ### Dense model (DNN)

# %%
dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=1)
])

history = compile_and_fit(dense, single_step_window)#, batch_size=32)   # , batch_size=32 added because running out of GPU memory

val_performance['Dense'] = dense.evaluate(single_step_window.val)
performance['Dense'] = dense.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0418 - val_loss: 0.0020 - val_mean_absolute_error: 0.0305
# Epoch 2/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0277 - val_loss: 0.0019 - val_mean_absolute_error: 0.0284
# Epoch 3/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0272 - val_loss: 0.0019 - val_mean_absolute_error: 0.0286
# Epoch 4/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0273 - val_loss: 0.0019 - val_mean_absolute_error: 0.0286
# Epoch 5/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0270 - val_loss: 0.0019 - val_mean_absolute_error: 0.0283
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0283

# %%
wide_window.plot(dense)

# %% [markdown]
# ### Evaluation

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ## Multi-step

# %% [markdown]
# ### Linear model

# %%
label_index = column_indices['NO2']
num_features = train_df.shape[1]

ms_linear = Sequential([
    Dense(1, kernel_initializer=tf.initializers.zeros)
])

history = compile_and_fit(ms_linear, multi_window)

ms_val_performance['Linear'] = ms_linear.evaluate(multi_window.val)
ms_performance['Linear'] = ms_linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0147 - mean_absolute_error: 0.0930 - val_loss: 0.0096 - val_mean_absolute_error: 0.0734
# Epoch 2/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0123 - mean_absolute_error: 0.0847 - val_loss: 0.0091 - val_mean_absolute_error: 0.0717
# Epoch 3/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0120 - mean_absolute_error: 0.0835 - val_loss: 0.0089 - val_mean_absolute_error: 0.0708
# Epoch 4/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0118 - mean_absolute_error: 0.0828 - val_loss: 0.0088 - val_mean_absolute_error: 0.0705
# Epoch 5/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0117 - mean_absolute_error: 0.0822 - val_loss: 0.0087 - val_mean_absolute_error: 0.0704
# Epoch 6/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0116 - mean_absolute_error: 0.0819 - val_loss: 0.0088 - val_mean_absolute_error: 0.0700
# Epoch 7/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0115 - mean_absolute_error: 0.0817 - val_loss: 0.0088 - val_mean_absolute_error: 0.0700
# Epoch 8/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0815 - val_loss: 0.0088 - val_mean_absolute_error: 0.0701
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0701

# %%
multi_window.plot(ms_linear)

# %% [markdown]
# ### Dense model (DNN)

# %%
ms_dense = Sequential([
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_dense, multi_window)

ms_val_performance['Dense'] = ms_dense.evaluate(multi_window.val)
ms_performance['Dense'] = ms_dense.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0129 - mean_absolute_error: 0.0863 - val_loss: 0.0084 - val_mean_absolute_error: 0.0691
# Epoch 2/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0110 - mean_absolute_error: 0.0794 - val_loss: 0.0084 - val_mean_absolute_error: 0.0680
# Epoch 3/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0108 - mean_absolute_error: 0.0786 - val_loss: 0.0098 - val_mean_absolute_error: 0.0725
# Epoch 4/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - mean_absolute_error: 0.0780 - val_loss: 0.0088 - val_mean_absolute_error: 0.0692
# Epoch 5/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0104 - mean_absolute_error: 0.0771 - val_loss: 0.0095 - val_mean_absolute_error: 0.0713
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.0713

# %%
multi_window.plot(ms_dense)

# %% [markdown]
# ### Evaluation

# %%
ms_mae_val = [v[1] for v in ms_val_performance.values()]
ms_mae_test = [v[1] for v in ms_performance.values()]

x = np.arange(len(ms_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=ms_performance.keys())
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ## Multi-output

# %% [markdown]
# ### Linear model

# %%
mo_linear = Sequential([
    Dense(units=2)
])

history = compile_and_fit(mo_linear, mo_single_step_window)

mo_val_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.val)
mo_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4057 - mean_absolute_error: 0.5095 - val_loss: 0.0654 - val_mean_absolute_error: 0.2018
# Epoch 2/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0406 - mean_absolute_error: 0.1661 - val_loss: 0.0267 - val_mean_absolute_error: 0.1348
# Epoch 3/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0218 - mean_absolute_error: 0.1213 - val_loss: 0.0144 - val_mean_absolute_error: 0.0970
# Epoch 4/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - mean_absolute_error: 0.0903 - val_loss: 0.0082 - val_mean_absolute_error: 0.0718
# Epoch 5/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0710 - val_loss: 0.0054 - val_mean_absolute_error: 0.0565
# Epoch 6/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0060 - mean_absolute_error: 0.0596 - val_loss: 0.0041 - val_mean_absolute_error: 0.0477
# Epoch 7/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0528 - val_loss: 0.0034 - val_mean_absolute_error: 0.0427
# Epoch 8/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0484 - val_loss: 0.0029 - val_mean_absolute_error: 0.0396
# Epoch 9/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0451 - val_loss: 0.0026 - val_mean_absolute_error: 0.0370
# Epoch 10/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0424 - val_loss: 0.0024 - val_mean_absolute_error: 0.0349
# Epoch 11/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0401 - val_loss: 0.0022 - val_mean_absolute_error: 0.0332
# Epoch 12/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0380 - val_loss: 0.0020 - val_mean_absolute_error: 0.0319
# Epoch 13/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0361 - val_loss: 0.0019 - val_mean_absolute_error: 0.0306
# Epoch 14/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0341 - val_loss: 0.0017 - val_mean_absolute_error: 0.0293
# Epoch 15/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0322 - val_loss: 0.0016 - val_mean_absolute_error: 0.0281
# Epoch 16/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0304 - val_loss: 0.0015 - val_mean_absolute_error: 0.0268
# Epoch 17/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0285 - val_loss: 0.0014 - val_mean_absolute_error: 0.0255
# Epoch 18/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0268 - val_loss: 0.0013 - val_mean_absolute_error: 0.0244
# Epoch 19/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0252 - val_loss: 0.0013 - val_mean_absolute_error: 0.0234
# Epoch 20/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0238 - val_loss: 0.0012 - val_mean_absolute_error: 0.0223
# Epoch 21/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0226 - val_loss: 0.0012 - val_mean_absolute_error: 0.0217
# Epoch 22/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0217 - val_loss: 0.0012 - val_mean_absolute_error: 0.0208
# Epoch 23/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0209 - val_loss: 0.0012 - val_mean_absolute_error: 0.0206
# Epoch 24/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0205 - val_loss: 0.0012 - val_mean_absolute_error: 0.0204
# Epoch 25/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0202 - val_loss: 0.0011 - val_mean_absolute_error: 0.0200
# Epoch 26/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0199 - val_loss: 0.0011 - val_mean_absolute_error: 0.0199
# Epoch 27/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0198 - val_loss: 0.0011 - val_mean_absolute_error: 0.0200
# Epoch 28/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0198 - val_loss: 0.0011 - val_mean_absolute_error: 0.0197
# Epoch 29/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.9773e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0011 - val_mean_absolute_error: 0.0199
# Epoch 30/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.9627e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0012 - val_mean_absolute_error: 0.0201
# Epoch 31/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.9671e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0011 - val_mean_absolute_error: 0.0200
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0200

# %%
mo_wide_window.plot(mo_linear)

# %% [markdown]
# ### Dense model (DNN)

# %%
mo_dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=2)
])

history = compile_and_fit(mo_dense, mo_single_step_window)

mo_val_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.val)
mo_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0381 - val_loss: 0.0012 - val_mean_absolute_error: 0.0223
# Epoch 2/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0219 - val_loss: 0.0013 - val_mean_absolute_error: 0.0230
# Epoch 3/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0211 - val_loss: 0.0012 - val_mean_absolute_error: 0.0216
# Epoch 4/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0212 - val_loss: 0.0012 - val_mean_absolute_error: 0.0219
# Epoch 5/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0206 - val_loss: 0.0011 - val_mean_absolute_error: 0.0198
# Epoch 6/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7266e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0013 - val_mean_absolute_error: 0.0225
# Epoch 7/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.8083e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0012 - val_mean_absolute_error: 0.0214
# Epoch 8/50
# 414/414 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7974e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0011 - val_mean_absolute_error: 0.0208
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0208

# %%
mo_wide_window.plot(mo_dense)

# %%
mo_mae_val = [v[1] for v in mo_val_performance.values()]
mo_mae_test = [v[1] for v in mo_performance.values()]

x = np.arange(len(mo_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=mo_performance.keys())
plt.legend(loc='best')
plt.tight_layout()
