# %%
import time
start = time.perf_counter()

# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2026-02-19 13:48:55.253148: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771526935.268295   10777 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771526935.272837   10777 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771526935.284418   10777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771526935.284439   10777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771526935.284441   10777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771526935.284442   10777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/ex_train.csv')
val_df = pd.read_csv('../data/ex_val.csv')
test_df = pd.read_csv('../data/ex_test.csv')

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (13239, 12) (3783, 12) (1892, 12)

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='NO2', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## Single-step model

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['NO2']) 
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['NO2'])

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units=1)
])

history = compile_and_fit(lstm_model, wide_window)

val_performance = {}
performance = {}

val_performance['LSTM'] = lstm_model.evaluate(wide_window.val)
performance['LSTM'] = lstm_model.evaluate(wide_window.test, verbose=0)
# Out:
# I0000 00:00:1771526937.002614   10777 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9668 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1
# Epoch 1/50
# I0000 00:00:1771526939.826628   10807 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0035 - mean_absolute_error: 0.0409 - val_loss: 0.0019 - val_mean_absolute_error: 0.0294
# Epoch 2/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0273 - val_loss: 0.0018 - val_mean_absolute_error: 0.0275
# Epoch 3/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0254 - val_loss: 0.0018 - val_mean_absolute_error: 0.0266
# Epoch 4/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0249 - val_loss: 0.0018 - val_mean_absolute_error: 0.0264
# Epoch 5/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0247 - val_loss: 0.0018 - val_mean_absolute_error: 0.0264
# Epoch 6/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0245 - val_loss: 0.0018 - val_mean_absolute_error: 0.0263
# Epoch 7/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0244 - val_loss: 0.0018 - val_mean_absolute_error: 0.0265
# Epoch 8/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0244 - val_loss: 0.0018 - val_mean_absolute_error: 0.0266
# Epoch 9/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0243 - val_loss: 0.0018 - val_mean_absolute_error: 0.0263
# Epoch 10/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0242 - val_loss: 0.0018 - val_mean_absolute_error: 0.0262
# Epoch 11/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0241 - val_loss: 0.0018 - val_mean_absolute_error: 0.0263
# Epoch 12/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0241 - val_loss: 0.0018 - val_mean_absolute_error: 0.0261
# Epoch 13/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0240 - val_loss: 0.0018 - val_mean_absolute_error: 0.0265
# Epoch 14/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0240 - val_loss: 0.0018 - val_mean_absolute_error: 0.0261
# Epoch 15/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0239 - val_loss: 0.0017 - val_mean_absolute_error: 0.0260
# Epoch 16/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0238 - val_loss: 0.0018 - val_mean_absolute_error: 0.0266
# Epoch 17/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0238 - val_loss: 0.0018 - val_mean_absolute_error: 0.0261
# Epoch 18/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0239 - val_loss: 0.0018 - val_mean_absolute_error: 0.0261
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0261

# %%
# Values obtained from chapter 14

mae_val = [0.029, 0.028, 0.029]
mae_test = [0.033, 0.032, 0.034]

# %%
wide_window.plot(lstm_model)

# %%
mae_val.append(val_performance['LSTM'][1])
mae_test.append(performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ## Multi-step model

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['NO2'])

# %%
ms_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_lstm_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.val)
ms_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0141 - mean_absolute_error: 0.0900 - val_loss: 0.0090 - val_mean_absolute_error: 0.0706
# Epoch 2/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0115 - mean_absolute_error: 0.0818 - val_loss: 0.0086 - val_mean_absolute_error: 0.0691
# Epoch 3/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0110 - mean_absolute_error: 0.0796 - val_loss: 0.0086 - val_mean_absolute_error: 0.0703
# Epoch 4/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0785 - val_loss: 0.0087 - val_mean_absolute_error: 0.0690
# Epoch 5/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0105 - mean_absolute_error: 0.0777 - val_loss: 0.0088 - val_mean_absolute_error: 0.0692
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0692

# %%
# Values obtained from chapter 14

ms_mae_val = [0.282, 0.282, 0.070, 0.071]
ms_mae_test = [0.243, 0.244, 0.115, 0.114]

# %%
ms_mae_val.append(ms_val_performance['LSTM'][1])
ms_mae_test.append(ms_performance['LSTM'][1])

x = np.arange(5)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ## Multi-output model

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['NO2','TEMP']) 
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['NO2','TEMP'])

# %%
print(column_indices['NO2'])
print(column_indices['TEMP'])
# Out:
# 3
# 6

# %%
mo_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units = 2)
])

history = compile_and_fit(mo_lstm_model, mo_wide_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.val)
mo_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0654 - val_loss: 0.0030 - val_mean_absolute_error: 0.0368
# Epoch 2/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0323 - val_loss: 0.0015 - val_mean_absolute_error: 0.0270
# Epoch 3/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0253 - val_loss: 0.0012 - val_mean_absolute_error: 0.0232
# Epoch 4/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0224 - val_loss: 0.0012 - val_mean_absolute_error: 0.0217
# Epoch 5/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0010 - mean_absolute_error: 0.0208 - val_loss: 0.0011 - val_mean_absolute_error: 0.0203
# Epoch 6/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.5581e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0011 - val_mean_absolute_error: 0.0197
# Epoch 7/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.2557e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0011 - val_mean_absolute_error: 0.0195
# Epoch 8/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.0661e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0011 - val_mean_absolute_error: 0.0190
# Epoch 9/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.9351e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0011 - val_mean_absolute_error: 0.0191
# Epoch 10/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.8330e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0011 - val_mean_absolute_error: 0.0189
# Epoch 11/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.7755e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0011 - val_mean_absolute_error: 0.0187
# Epoch 12/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.7142e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0011 - val_mean_absolute_error: 0.0188
# Epoch 13/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.6536e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0011 - val_mean_absolute_error: 0.0187
# Epoch 14/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 8.6288e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0011 - val_mean_absolute_error: 0.0186
# Epoch 15/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.5572e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0011 - val_mean_absolute_error: 0.0187
# Epoch 16/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.5397e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0011 - val_mean_absolute_error: 0.0186
# Epoch 17/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.4775e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0011 - val_mean_absolute_error: 0.0187
# Epoch 18/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.4457e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0011 - val_mean_absolute_error: 0.0186
# Epoch 19/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.4302e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0011 - val_mean_absolute_error: 0.0187
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0187

# %%
mo_wide_window.plot(mo_lstm_model)

# %%
# Values from chapter 14

mo_mae_val = [0.021, 0.020, 0.020]
mo_mae_test = [0.025, 0.023, 0.025]

# %%
mo_mae_val.append(mo_val_performance['LSTM'][1])
mo_mae_test.append(mo_performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

# %%
end = time.perf_counter()

elapsed_time = end - start
print(f"Elapsed time: {elapsed_time:.4f} seconds")
# Out:
# Elapsed time: 109.8427 seconds

# %% [markdown]
# Python 3.12, tensorflow 2.19.1, LSTM, Elapsed time: 109.8427 seconds
